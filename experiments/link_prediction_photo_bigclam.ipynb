# %%
import os

# Set the PYDEVD_WARN_SLOW_RESOLVE_TIMEOUT environment variable to 0.6 seconds
# os.environ['PYDEVD_WARN_SLOW_RESOLVE_TIMEOUT'] = '0.7'

import torch
import matplotlib.pyplot as plt
import networkx as nx
import collections

from copy import deepcopy

# local
import optimization_utils as ou

import sys
if '..' not in sys.path:
    sys.path.insert(0, '..')


from datasets.import_dataset import import_dataset
from trainer import Trainer
from utils.plotting import *
from utils import utils
from utils import utils_pyg as up
import datasets.simulations as sim
import link_prediction as lp





device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'device = {device}')


# %load_ext autoreload
# %autoreload 2
# Out:
# device = cuda

# %%
# densification for link prediction: take a subgraph that is not
# link prediction: i know some of the nodes and a bunch is dyads on which i need to predict. so take a subgraph 
# so do a densification on all of the edges you have and omitted dyads are the same

#densification. need to do a special densification here. separate between 1 and 0 after the dyads were omitted. so the dyads omittion needs to happen before the densification which makes everything ugly. why does the dyads omittion happen when it does? i think that the m

# %% [markdown]
# # Grid search params

# %% [markdown]
# ## VANILLA

# %% [markdown]
# ### photo bigclam

# %%
dim_feats = [36, 60, 76, 80, 96, 100, 110, 116]
# dim_feats = [24]
l1_regs = [0.1, 0.0]
# l1_regs = [0.0, 0.01, 0.1, 1, 10]
# s_regs = [10, 1, 0.1, 0.01, 0.0]
s_regs = [0.0]
# n_iters = [4000]
n_iters = [4000]
lr_feats = [3e-6]

range_triplets = [
    ['clamiter_init', 'dim_feat', dim_feats],
    ['clamiter_init','s_reg', s_regs],
    ['clamiter_init','l1_reg', l1_regs],
    ['feat_opt','n_iter', n_iters],
    ['feat_opt','lr', lr_feats]
]
#todo: how to default without the range triplets? if i just want to make optimization for many iterations on the mighty or the specialized?

#todo: why is the l1 reg not working
# Create the file if it doesn't exist
ds_name = 'photo'
model_name = 'bigclam'
global_config_base = True
densify = False
attr_opt = False
test_p = 0.0
val_p = 0.1

ou.cross_val_link(
    ds_name,
    model_name=model_name,
    range_triplets=range_triplets,
    global_config_base=global_config_base,
    densify=densify,
    attr_opt=attr_opt,
    test_p=test_p,
    val_p=val_p,
    device=device,
    n_reps=10,
    plot_every=-1
    )

#todo: maybe try to optimize with small learning rate at the beginning? maybe the prior will just take care of it....
#todo: also use node attributes!! for sparse graphs they are important
# Out:
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:43:18 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.971629374151814
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:44:18 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9722855731692915
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:45:15 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9737019315114323
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:46:06 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9734228371994784
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:46:52 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9737640933886378
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:47:38 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9742858902135046
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:48:27 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9743407214398716
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:49:20 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.972689889883595
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:50:07 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9743618526483055
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:50:56 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9741279539207259
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:51:50 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9722942967804082
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:52:50 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.973007445314395
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:53:51 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9740170175323956
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:54:51 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9734014049288973
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:55:51 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9748739360617693
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:56:52 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9727948254588257
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:57:52 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9734050172694763
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:58:53 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9722070589908365
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-28 23:59:52 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9730180483225941
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:00:56 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 36,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.973932864090287
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:02:35 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9764298241214032
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:04:17 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.972751354557452
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:06:27 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.97386396996713
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:08:43 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.976060383766645
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:10:59 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9734134762549003
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:13:18 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9743785779281036
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:16:09 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9740830128656881
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:19:37 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.976486526563218
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:23:02 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9747450801983258
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:26:26 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9749556177058046
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:29:51 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9740224100024865
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:33:14 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.976883868554814
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:36:35 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9744201344850889
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:39:52 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9747813877087383
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:43:08 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9746232687177001
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:46:23 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9747813862959802
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:49:38 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9761997333035938
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:52:55 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9735772535876105
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:56:11 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9750501286300809
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 00:59:28 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 60,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.974765597010939
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:02:43 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.97557308299566
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:06:03 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9743067413011968
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:09:22 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9758674473408373
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:12:42 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9758411530051451
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:16:00 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9758518684439534
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:19:23 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9755628610879109
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:22:44 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9757924205834906
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:26:11 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9757885371893275
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:29:40 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.976379053386405
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:33:07 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9732546254718711
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:36:21 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9769624192046926
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:39:33 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9744244539351669
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:42:44 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9762317704374193
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:45:55 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9751814037776906
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:49:04 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9760549623228111
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 01:52:18 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 76,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
# ...
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9777965437710202
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 06:33:02 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9777656799349151
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 06:36:18 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9763470992739316
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 06:39:35 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9770874804197851
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 06:42:53 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.977439598752723
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 06:46:11 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9771126742092262
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 06:49:29 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9773983038127618
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 06:52:45 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9764829399889975
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 06:56:00 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9777684145342497
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 06:59:16 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9778371234644587
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 07:02:33 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.977644831645667
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 07:05:54 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9773120361561467
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 07:09:11 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9780292057465336
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 07:12:28 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9777371447869737
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 07:15:46 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9774614419723149
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 07:19:02 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9765352715091891
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 07:22:19 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9764952466526386
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 07:25:36 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9782297948686938
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-29 07:28:53 starting optimization of bigclam on photo on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 116,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 0.0,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 4000,
#         "early_stop": 0
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:369:::
# fit wrapper fit_feats, plotting state at iter 3999
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:415:::
#
#
# FINISHED train
#  last accuracies:
# test
# auc: None
# val
# key='auc': 0.9765464403960834
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:429:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/optimization_utils.py

]
#todo: how to default without the range triplets? if i just want to make optimization for many iterations on the mighty or the specialized?

#todo: why is the l1 reg not working
# Create the file if it doesn't exist
ds_name = 'photo'
model_name = 'piegam'
global_config_base = True
densify = False
attr_opt = False #! TRY WITHOUT ATTRIBUTES!!!!
test_p = 0.1
val_p = 0.0

ou.cross_val_link(
    ds_name,
    model_name=model_name,
    range_triplets=range_triplets,
    global_config_base=global_config_base,
    densify=densify,
    attr_opt=attr_opt,
    test_p=test_p,
    val_p=val_p,
    device=device,
    n_reps=6
    )


#todo: more prior iterations, less noise amp. more power to prior in general!!
# Out:
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:00:54 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.721995833504625
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:03:04 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.6770318047276466
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:05:16 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7219958335046249
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:07:26 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.6742054943473793
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:09:34 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7127460904419322
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:11:41 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7456340657759508
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:13:48 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.05,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7428077553956834
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:15:56 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.05,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.6862815477903392
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:18:04 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.05,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.722252770811922
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:20:11 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.05,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.6855107358684481
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:22:19 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.05,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.6762609928057555
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:24:27 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.05,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7137738396711203
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:26:34 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.01,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7173709619732785
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:28:42 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.01,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7502589373072972
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:30:49 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.01,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7440924419321686
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:32:57 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.01,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7733832949640288
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:35:05 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.01,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7507728119218912
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:37:13 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 1e-06,
#         "noise_amp": 0.01,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.6793442404933197
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:39:20 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 3e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.76207805344296
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:41:28 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 3e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7908550318602262
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:43:36 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 3e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7225097081192189
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:45:44 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 3e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.763105802672148
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:47:52 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 3e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7810914141829393
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 13:50:00 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 500,
#         "lr": 3e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
# ...
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.8353051860226106
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 15:02:47 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 1000,
#         "lr": 1e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7219958335046248
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 15:05:50 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 1000,
#         "lr": 1e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7654182384378213
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 15:08:49 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 1000,
#         "lr": 1e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7990770256937307
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 15:11:49 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 1000,
#         "lr": 1e-06,
#         "noise_amp": 0.1,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.6575045693730731
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 15:14:51 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 1000,
#         "lr": 1e-06,
#         "noise_amp": 0.05,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7556546207605345
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 15:17:59 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 1000,
#         "lr": 1e-06,
#         "noise_amp": 0.05,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.6796011778006167
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 15:21:09 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 1000,
#         "lr": 1e-06,
#         "noise_amp": 0.05,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 3/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 4/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 5/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 6/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:658:::
# fit, plotting state at iter 6.
# dataset: texas, ,model: piegam
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:664:::
# fit end, no early stopping
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:416:::
#
#
# FINISHED train
#  last accuracies:
# auc: 0.7137738396711204
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:422:::
#
#
#
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../trainer.py:316:::
#  2024-09-26 15:24:14 starting optimization of piegam on texas on device cuda
#
#  configs_dict:
# {
#     "clamiter_init": {
#         "dim_feat": 24,
#         "dim_attr": 100,
#         "s_reg": 0.0,
#         "l1_reg": 1,
#         "T": 1,
#         "hidden_dim": 64,
#         "num_coupling_blocks": 32,
#         "num_layers_mlp": 2
#     },
#     "feat_opt": {
#         "lr": 3e-06,
#         "n_iter": 500,
#         "early_stop": 0
#     },
#     "prior_opt": {
#         "n_iter": 1000,
#         "lr": 1e-06,
#         "noise_amp": 0.05,
#         "weight_decay": 0.1,
#         "early_stop": 0
#     },
#     "back_forth": {
#         "n_back_forth": 6,
#         "scheduler_step_size": 1000,
#         "scheduler_gamma": 0.5,
#         "early_stop_fit": 0,
#         "first_func_in_fit": "fit_feats"
#     }
# }
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:541:::
# in fit,
# first_func_in_fit='fit_feats'
# second_function_name='fit_prior'
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 1/6
#
#
# /home/user/Documents/danny/AAAI_pieclam/experiments/../clamiter.py:600:::
# back and forth 2/6

# %%
import matplotlib.pyplot as plt

# Extract the data for bigclam and iegam
bigclam_data = acc_dict['bigclam']
iegam_data = acc_dict['iegam']

# Plot the data
for key in bigclam_data.keys():
    for data in bigclam_data[key]:
        plt.plot(key,data,'o', color='blue', label='bigclam', linestyle='none')
for key in iegam_data.keys():
    for data in iegam_data[key]:
        plt.plot(key,data, 'o', color='red', label='iegam', linestyle='none')

# ithink maybe 40 for big and 80 for ie

# %%
acc_dict
import matplotlib.pyplot as plt

# Extract the data for bigclam and iegam
bigclam_data = acc_dict['bigclam']
iegam_data = acc_dict['iegam']

# Plot the data
for key in bigclam_data.keys():
    plt.plot(dim_feats, bigclam_data[key], 'o', color='blue', label='bigclam', linestyle='none')
    plt.plot(dim_feats, iegam_data[key], 'o', color='red', label='iegam', linestyle='none')
    

# plt.plot(dim_feats, bigclam_data, color='blue', label='bigclam')
# plt.plot(dim_feats, iegam_data, color='red', label='iegam')

# # Add labels and title
# plt.xlabel('Dim Feat')
# plt.ylabel('AUC')
# plt.title('AUC vs Dim Feat')

# # Add legend
# plt.legend()

# # Show the plot
# plt.show()

# %%
acc_dict
# Out:
# {'bigclam': {36: [0.9727175209227668, 0.9723776342604988],
#   40: [0.972267407076946, 0.9718492448404841],
#   50: [0.9763531931124269, 0.9762211485460616]},
#  'iegam': {36: [0.9655798708689162, 0.9567564327892888],
#   40: [0.9570085710707769, 0.9578119610378143],
#   50: [0.9598908052110603, 0.9617079782205947]}}

# %%
#   'bigclam': {
#   10: [0.9585404724760899, 0.9639035086504821],
#   20: [0.9684866796298274, 0.9682561623880347],
#   30: [0.9715515773390894, 0.9679066481381807],
#   40: [0.973401410354128, 0.975028281881877]},
#  'iegam': {
#   10: [0.9363348119751429, 0.9362004879243281],
#   20: [0.953740656284433, 0.9519222289221715],
#   30: [0.9568455111402209, 0.9550952164216329],
#   40: [0.9605243983039492, 0.9610890825556342]}}
