# %%
import os
import pandas as pd

import sys
if '..' not in sys.path:
    sys.path.insert(0, '..')

import optimization_utils as ou


def print_folder(folder_path):
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.json'):
            file_path = os.path.join(folder_path, file_name)
            grouped_df = ou.SaveRun.load_saved(file_path)
            print(file_name + '\n==================\n')
            print(grouped_df.head(10))




# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print('photo iegam:')

print_folder('link_prediction/photo/iegam')

print('photo bigclam:')

print_folder('link_prediction/photo/bigclam')
# Out:
# photo iegam:
# acc_configs_3.json
# ...
#
#     avg_acc   std_acc  count  clamiter_init_dim_feat  clamiter_init_s_reg  \
# 0  0.964026  0.001379     10                      66                  0.0
# 1  0.963387  0.001091     10                      60                  0.0
# 2  0.962902  0.001446     10                      56                  0.0
# 3  0.962894  0.001344     10                      50                  0.0
# 4  0.962713  0.000857     10                      46                  0.0
# 5  0.962242  0.001502     10                      40                  0.0
# 6  0.961452  0.001588     10                      36                  0.0
#
#    clamiter_init_l1_reg  feat_opt_n_iter  feat_opt_lr
# 0                     1             6000     0.000003
# 1                     1             6000     0.000003
# 2                     1             6000     0.000003
# 3                     1             6000     0.000003
# 4                     1             6000     0.000003
# ...

# %%
# print('texas bigclam:\n=============\n')
# print_folder('link_prediction/texas/bigclam')

# print('texas iegam:\n=============\n')
# print_folder('link_prediction/texas/iegam')

# print('texas pclam:\n=============\n')
# print_folder('link_prediction/texas/pclam')

print('texas piegam:\n=============\n')
print_folder('link_prediction/texas/piegam')
# Out:
# texas piegam:
# ...
#
# acc_configs_3.json
# ...
#
#     avg_acc   std_acc  count  clamiter_init_dim_feat  clamiter_init_s_reg  \
# 0  0.708426  0.029301      5                      24                  0.0
#
#    clamiter_init_l1_reg  feat_opt_n_iter  feat_opt_lr  prior_opt_n_iter  \
# 0                     1              500      0.00001              1000
#
#    prior_opt_lr  prior_opt_noise_amp  back_forth_scheduler_step_size  \
# 0      0.000003                  0.1                            1000
#
#    back_forth_n_back_forth
# 0                        6
# acc_configs_5.json
# ...
#
#     avg_acc  std_acc  count  clamiter_init_dim_feat  clamiter_init_s_reg  \
# 0  0.710849      NaN      1                      24                  0.0
#
#    clamiter_init_l1_reg  feat_opt_n_iter  feat_opt_lr  prior_opt_n_iter  \
# 0                     1              500      0.00001              1000
#
#    prior_opt_lr  prior_opt_noise_amp  back_forth_scheduler_step_size  \
# ...

# %% [markdown]
# ## Hopkins

# %%
print('hopkins bigclam:\n=============\n')
print_folder('link_prediction/JohnsHopkins55/bigclam')

print('hopkins iegam:\n=============\n')
print_folder('link_prediction/JohnsHopkins55/iegam')

print('hopkins pclam:\n=============\n')
print_folder('link_prediction/JohnsHopkins55/pclam')

print('hopkins piegam:\n=============\n')
print_folder('link_prediction/JohnsHopkins55/piegam')
# Out:
# hopkins bigclam:
# ...
#
# acc_configs_0.json
# ...
#
#     avg_acc   std_acc  count  clamiter_init_dim_feat  clamiter_init_s_reg  \
# 0  0.947613  0.000657      3                     110                  0.0
# 1  0.947269  0.000559      3                     100                  0.0
# 2  0.946854  0.000513      3                      96                  0.0
# 3  0.946810  0.000613      3                      86                  0.0
# 4  0.946515  0.000483      3                     106                  0.0
# 5  0.946462  0.000348      3                      80                  0.0
# 6  0.946213  0.000152      3                      90                  0.0
# 7  0.945808  0.000857      3                      76                  0.0
#
#    clamiter_init_l1_reg  feat_opt_n_iter  feat_opt_lr
# 0                     1             7000     0.000003
# 1                     1             7000     0.000003
# 2                     1             7000     0.000003
# ...

# %%
print('squirrel bigclam:\n=============\n')
print_folder('link_prediction/squirrel/bigclam')

print('squirrel iegam:\n=============\n')
print_folder('link_prediction/squirrel/iegam')

print('squirrel pclam:\n=============\n')
print_folder('link_prediction/squirrel/pclam')

print('squirrel piegam:\n=============\n')
print_folder('link_prediction/squirrel/piegam')
# Out:
# squirrel bigclam:
# ...
#
# acc_configs_0.json
# ...
#
#     avg_acc  std_acc  count  clamiter_init_dim_feat  clamiter_init_l1_reg
# 0  0.977995      NaN      1                      36                    10
# squirrel iegam:
# ...
#
# acc_configs_1.json
# ...
#
#    avg_test_acc  std_test_acc  avg_val_acc  std_val_acc  count  \
# 0      0.980750      0.001177     0.981059     0.001397      6
# 1      0.980561      0.001173     0.980958     0.001396      6
# 2      0.980637      0.001146     0.980779     0.000820      6
# 3      0.980598      0.000831     0.980763     0.001328      6
# 4      0.980413      0.000913     0.980735     0.000613      6
# 5      0.980708      0.000144     0.980707     0.001014      6
# 6      0.980051      0.001265     0.980639     0.001407      6
# 7      0.980229      0.001277     0.980611     0.001326      3
# 8      0.980324      0.001580     0.980458     0.001163      6
# 9      0.980607      0.000614     0.980398     0.000821      6
#
# ...
