# %%
import sys
if '../..' not in sys.path:
    sys.path.insert(0, '../..')

from utils import saving_utils as su

# %%
grouped_df_iegam = su.SaveRun.load_saved('link_prediction/photo/iegam/acc_configs_2.json')
print(grouped_df_iegam)

grouped_df_bigclam = su.SaveRun.load_saved('link_prediction/photo/bigclam/acc_configs_0.json')
print(grouped_df_bigclam)



#todo: it's data analysis tasks from now. you want to have to plot the results as a function of the number of communities for the different regularizations. PICK NUM COMMUNITIES

#todo: cluster the same with test and val

#todo: do regularizations make a difference? does the validation follow the test score well? how many communities to use?
# Out:
#     clamiter_init_dim_feat  clamiter_init_l1_reg  clamiter_init_s_reg  \
# 0                       76                  0.01                 0.10
# 1                       60                  1.00                 0.10
# 2                       36                  1.00                 0.01
# 3                       66                  0.10                 1.00
# 4                       60                  0.10                 1.00
# ..                     ...                   ...                  ...
# 85                      66                  0.01                 0.01
# 86                      46                  0.10                 0.01
# 87                      56                  0.01                 0.10
# 88                      46                  0.01                 0.10
# 89                      40                  0.01                 0.10
#
#      avg_acc   std_acc
# 0   0.973584  0.000621
# 1   0.973240  0.000904
# 2   0.973214  0.000834
# 3   0.973182  0.001200
# ...
